# %% [markdown]
# # Plotting and Visualization

# %%
import numpy as np
import pandas as pd
PREVIOUS_MAX_ROWS = pd.options.display.max_rows
pd.options.display.max_rows = 20
np.random.seed(12345)
import matplotlib.pyplot as plt
import matplotlib
plt.rc('figure', figsize=(10, 6)) #long10， wide6
np.set_printoptions(precision=4, suppress=True) #decimal 4

# %%
# %matplotlib inline
#change here; 1) code, 2) inline

# %% [markdown]
# ## A Brief matplotlib API Primer

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np
data = np.arange(10)
data
plt.plot(data)

# %% [markdown]
# ### Figures and Subplots

# %%
fig = plt.figure()

# %%
ax1 = fig.add_subplot(2, 2, 1)

# %%
ax2 = fig.add_subplot(2, 2, 2)
ax3 = fig.add_subplot(2, 2, 3)

# %% [markdown]
# fig = plt.figure()
# ax1 = fig.add_subplot(2, 2, 1)
# ax2 = fig.add_subplot(2, 2, 2)
# ax3 = fig.add_subplot(2, 2, 3)

# %%
plt.plot(np.random.randn(50).cumsum(), 'k--')

# %%
_ = ax1.hist(np.random.randn(100), bins=20, color='k', alpha=0.3)
ax2.scatter(np.arange(30), np.arange(30) + 3 * np.random.randn(30))

# %%
plt.close('all')

# %%
fig, axes = plt.subplots(2, 3)
axes

# %% [markdown]
# #### Adjusting the spacing around subplots

# %% [markdown]
# subplots_adjust(left=None, bottom=None, right=None, top=None,
#                 wspace=None, hspace=None)

# %% [markdown]
# fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
# for i in range(2):
#     for j in range(2):
#         axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
# plt.subplots_adjust(wspace=0, hspace=0)

# %%
fig, axes = plt.subplots(2, 2, sharex=True, sharey=True)
for i in range(2):
    for j in range(2):
        axes[i, j].hist(np.random.randn(500), bins=50, color='k', alpha=0.5)
plt.subplots_adjust(wspace=0, hspace=0)

# %% [markdown]
# ### Colors, Markers, and Line Styles

# %% [markdown]
# ax.plot(x, y, 'g--')

# %% [markdown]
# ax.plot(x, y, linestyle='--', color='g')

# %%
plt.figure()

# %%
from numpy.random import randn
plt.plot(randn(30).cumsum(), 'ko--')

# %% [markdown]
# plot(randn(30).cumsum(), color='k', linestyle='dashed', marker='o')

# %%
plt.close('all')

# %%
data = np.random.randn(30).cumsum()
plt.plot(data, 'k--', label='Default')
plt.plot(data, 'k-', drawstyle='steps-post', label='steps-post')
plt.legend(loc='best')

# %% [markdown]
# ### Ticks, Labels, and Legends

# %% [markdown]
# #### Setting the title, axis labels, ticks, and ticklabels

# %%
fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)
ax.plot(np.random.randn(1000).cumsum())

# %%
ticks = ax.set_xticks([0, 250, 500, 750, 1000])
labels = ax.set_xticklabels(['one', 'two', 'three', 'four', 'five'],
                            rotation=30, fontsize='small')

# %%
ax.set_title('My first matplotlib plot')
ax.set_xlabel('Stages')

# %% [markdown]
# props = {
#     'title': 'My first matplotlib plot',
#     'xlabel': 'Stages'
# }
# ax.set(**props)

# %% [markdown]
# #### Adding legends

# %%
from numpy.random import randn
fig = plt.figure(); ax = fig.add_subplot(1, 1, 1)
ax.plot(randn(1000).cumsum(), 'k', label='one')
ax.plot(randn(1000).cumsum(), 'k--', label='two')
ax.plot(randn(1000).cumsum(), 'k.', label='three')

# %%
ax.legend(loc='best')

# %% [markdown]
# ### Annotations and Drawing on a Subplot

# %% [markdown]
# ax.text(x, y, 'Hello world!',
#         family='monospace', fontsize=10)

# %%
from datetime import datetime

fig = plt.figure()
ax = fig.add_subplot(1, 1, 1)

data = pd.read_csv('examples/spx.csv', index_col=0, parse_dates=True)
spx = data['SPX']

spx.plot(ax=ax, style='k-')

crisis_data = [
    (datetime(2007, 10, 11), 'Peak of bull market'),
    (datetime(2008, 3, 12), 'Bear Stearns Fails'),
    (datetime(2008, 9, 15), 'Lehman Bankruptcy')
]

for date, label in crisis_data:
    ax.annotate(label, xy=(date, spx.asof(date) + 75),
                xytext=(date, spx.asof(date) + 225),
                arrowprops=dict(facecolor='black', headwidth=4, width=2,
                                headlength=4),
                horizontalalignment='left', verticalalignment='top')

# Zoom in on 2007-2010
ax.set_xlim(['1/1/2007', '1/1/2011'])
ax.set_ylim([600, 1800])

ax.set_title('Important dates in the 2008-2009 financial crisis')

# %%
ax.set_title('Important dates in the 2008–2009 financial crisis')

# %% [markdown]
# fig = plt.figure()
# ax = fig.add_subplot(1, 1, 1)
#
# rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
# circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
# pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
#                    color='g', alpha=0.5)
#
# ax.add_patch(rect)
# ax.add_patch(circ)
# ax.add_patch(pgon)

# %%
fig = plt.figure(figsize=(12, 6)); ax = fig.add_subplot(1, 1, 1)
rect = plt.Rectangle((0.2, 0.75), 0.4, 0.15, color='k', alpha=0.3)
circ = plt.Circle((0.7, 0.2), 0.15, color='b', alpha=0.3)
pgon = plt.Polygon([[0.15, 0.15], [0.35, 0.4], [0.2, 0.6]],
                   color='g', alpha=0.5)
ax.add_patch(rect)
ax.add_patch(circ)
ax.add_patch(pgon)

# %% [markdown]
# ### Saving Plots to File

# %% [markdown]
# plt.savefig('figpath.svg')

# %% [markdown]
# plt.savefig('figpath.png', dpi=400, bbox_inches='tight')

# %% [markdown]
# from io import BytesIO
# buffer = BytesIO()
# plt.savefig(buffer)
# plot_data = buffer.getvalue()

# %% [markdown]
# ### matplotlib Configuration

# %% [markdown]
# plt.rc('figure', figsize=(10, 10))

# %% [markdown]
# font_options = {'family' : 'monospace',
#                 'weight' : 'bold',
#                 'size'   : 'small'}
# plt.rc('font', **font_options)

# %% [markdown]
# ## Plotting with pandas and seaborn

# %% [markdown]
# ### Line Plots

# %%
plt.close('all')

# %%
s = pd.Series(np.random.randn(10).cumsum(), index=np.arange(0, 100, 10))
#10 numbers from a univariate normal, cumulative. Then index the numbers.

# %%
s
# Out:
# 0    -0.204708
# 10    0.274236
# 20   -0.245203
# 30   -0.800933
# 40    1.164847
# 50    2.558253
# 60    2.651161
# 70    2.932907
# 80    3.701930
# 90    4.948364
# dtype: float64

# %%
s.plot()

# %%
df = pd.DataFrame(np.random.randn(10, 4).cumsum(0),
                  columns=['A', 'B', 'C', 'D'],
                  index=np.arange(0, 100, 10)) #index for arrays (rows)
#2 dimentional array, 10 rows*4 columns, cumulative. 
#0 in cumsum(0) means that is adding over axis=0.
#axis=0, sum over rows for each of the 4 columns
#axis=1, sum over columns for each of the 10 rows

# %%
df
# Out:
#            A         B         C         D
# 0   0.203887 -2.213737  0.315042 -0.137200
# 10  0.240125 -1.455922  1.859311 -1.865243
# 20  1.033518 -1.803597  2.211809 -0.836944
# 30  2.230032 -1.927094  0.879765 -1.084140
# 40  3.406025 -0.251688  1.553956 -1.194793
# 50  0.223357  0.214210  1.113785 -0.193597
# 60 -0.828693 -0.777559  1.470380 -0.562270
# 70  0.075452  0.388868 -0.054989 -0.853877
# 80 -1.797094 -0.447511 -0.635205 -1.027710
# 90 -0.314108  1.491070 -1.541428 -1.198946

# %%
df.plot()

# %% [markdown]
# ### Bar Plots

# %%
fig, axes= plt.subplots(2, 1) #creat a grid 2*1 of plots: axes[0] axes[1] 
data = pd.Series(np.random.rand(16), index=list('abcdefghijklmnop'))
data.plot.bar(ax=axes[0], color='k', alpha=0.7) #k = black, alpha(transparency)
data.plot.barh(ax=axes[1], color='b', alpha=0.7) #A horizontal bar plot

# %% [markdown]
# Alias	Color
# 'b'	blue
# 'g'	green
# 'r'	red
# 'c'	cyan
# 'm'	magenta
# 'y'	yellow
# 'k'	black
# 'w'	white

# %%
data
# Out:
# a    0.973230
# b    0.634054
# c    0.888422
# d    0.495415
# e    0.351617
# f    0.714230
# g    0.503929
# h    0.225638
# i    0.244974
# j    0.792801
# k    0.495172
# l    0.915094
# m    0.945372
# n    0.533232
# o    0.252493
# p    0.720862
# dtype: float64

# %%
np.random.seed(12348)
#So what exactly is NumPy random seed?
#NumPy random seed is simply a function that sets the random seed of the NumPy pseudo-random number generator. 
#It provides an essential input that enables NumPy to generate pseudo-random numbers for random processes.

# %%
df = pd.DataFrame(np.random.rand(6, 4), #6 rows (arrays) * 4 columns, 
                  index=['one', 'two', 'three', 'four', 'five', 'six'], #index for arrays (rows)
                  columns=pd.Index(['A', 'B', 'C', 'D'], name='Genus')) # use "index" in pandas to give names of columns

# %%
df
# Out:
# Genus         A         B         C         D
# one    0.370670  0.602792  0.229159  0.486744
# two    0.420082  0.571653  0.049024  0.880592
# three  0.814568  0.277160  0.880316  0.431326
# four   0.374020  0.899420  0.460304  0.100843
# five   0.433270  0.125107  0.494675  0.961825
# six    0.601648  0.478576  0.205690  0.560547

# %%
df.plot.bar()

# %%
#plt.figure()

# %%
df.plot.barh(stacked=True, alpha=0.5) #horizontal stacked bar

# %%
plt.close('all')

# %%
tips = pd.read_csv('examples/tips.csv')
party_counts = pd.crosstab(tips['day'], tips['size']) # cross-tabulation: calcualte frequency. select 'day' as row, 'size' as column.
party_counts
# Not many 1- and 6-person parties
party_counts = party_counts.loc[:, 2:5] 
#all rows. loc: column names from '0' to '5', including '5'. names happen to be numbers. 
#iloc: column positions from 2 to 5, excluding 5.

# %%
party_counts
# Out:
# size   2   3   4  5
# day
# Fri   16   1   1  0
# Sat   53  18  13  1
# Sun   39  15  18  3
# Thur  48   4   5  1

# %%
# Sum(1): Normalize to sum to 1
party_pcts = party_counts.div(party_counts.sum(1), axis=0) #??
#axis can only be 0 or 1. axis : {0 or ‘index’, 1 or ‘columns’} 
#Whether to compare by the index (0 or ‘index’) or columns (1 or ‘columns’). For Series input, axis to match Series index on.
party_pcts
party_pcts.plot.bar()

# %%
party_pcts
# Out:
# size         2         3         4         5
# day
# Fri   0.888889  0.055556  0.055556  0.000000
# Sat   0.623529  0.211765  0.152941  0.011765
# Sun   0.520000  0.200000  0.240000  0.040000
# Thur  0.827586  0.068966  0.086207  0.017241

# %%
plt.close('all')

# %%
import seaborn as sns
tips['tip_pct'] = tips['tip'] / (tips['total_bill'] - tips['tip'])
#tips.head()
sns.barplot(x='tip_pct', y='day', data=tips, orient='h')
#A bar plot represents an estimate of central tendency for a numeric variable with the height of each rectangle 
#and provides some indication of the uncertainty around that estimate using error bars.
# Confidence Internal，by bootrapping.

# %%
tips.head() #have a look, first 5 rows.
# Out:
#    total_bill   tip smoker  day    time  size   tip_pct
# 0       16.99  1.01     No  Sun  Dinner     2  0.063204
# 1       10.34  1.66     No  Sun  Dinner     3  0.191244
# 2       21.01  3.50     No  Sun  Dinner     3  0.199886
# 3       23.68  3.31     No  Sun  Dinner     2  0.162494
# 4       24.59  3.61     No  Sun  Dinner     4  0.172069

# %%
plt.close('all')

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h') # hue lists all categories of 'time'.

# %%
plt.close('all')

# %%
sns.set(style="whitegrid") 
#style : dict, None, or one of {darkgrid, whitegrid, dark, white, ticks}
# A dictionary of parameters or the name of a preconfigured set.

# %%
sns.barplot(x='tip_pct', y='day', hue='time', data=tips, orient='h') # hue lists all categories of 'time'.

# %% [markdown]
# ### Histograms and Density Plots

# %%
plt.figure()

# %%
tips['tip_pct'].plot.hist(bins=50) #50 bars.

# %%
plt.figure()

# %%
tips['tip_pct'].plot.density()

# %%
plt.figure()

# %%
comp1 = np.random.normal(0, 1, size=200) # mean=0, standard deviation=1, 200 values
comp2 = np.random.normal(10, 2, size=200)
values = pd.Series(np.concatenate([comp1, comp2])) 
#numpy.concatenate - Concatenation refers to joining. 
#This function is used to join two or more arrays of the same shape along a specified axis.
sns.distplot(values, bins=100, color='k') #distribution plot

# %%
values
# Out:
# 0      -1.221896
# 1       0.446805
# 2       0.832024
# 3      -0.043014
# 4      -0.024175
# 5      -0.759594
# 6       0.994835
# 7       0.634475
# 8      -0.848585
# 9       0.351294
#          ...
# 390     8.393219
# 391     7.024756
# 392     8.338029
# 393    11.696468
# 394     9.891269
# 395    11.268679
# 396    10.284635
# 397     8.435401
# 398    10.391260
# 399    10.828079
# Length: 400, dtype: float64

# %% [markdown]
# ### Scatter or Point Plots

# %%
macro = pd.read_csv('examples/macrodata.csv')
data = macro[['cpi', 'm1', 'tbilrate', 'unemp']]
trans_data = np.log(data).diff().dropna() #take the natural log, then first differencing, then drop NaN. 
trans_data[-5:] #show the last 5 rows.
# Out:
#           cpi        m1  tbilrate     unemp
# 198 -0.007904  0.045361 -0.396881  0.105361
# 199 -0.021979  0.066753 -2.277267  0.139762
# 200  0.002340  0.010286  0.606136  0.160343
# 201  0.008419  0.037461 -0.200671  0.127339
# 202  0.008894  0.012202 -0.405465  0.042560

# %%
plt.figure()

# %%
sns.regplot('m1', 'unemp', data=trans_data) #plot of regression. 
plt.title('Changes in log %s versus log %s' % ('m1', 'unemp')) # '%s' as placeholder
# Out:
# Text(0.5, 1.0, 'Changes in log m1 versus log unemp')

# %%
sns.pairplot(trans_data, diag_kind='kde', plot_kws={'alpha': 0.2}) #kernel density

# %% [markdown]
# ### Facet Grids and Categorical Data

# %%
sns.factorplot(x='day', y='tip_pct', hue='time', col='smoker',
               kind='bar', data=tips[tips.tip_pct < 1])
# Out:
# D:\Users\Lenovo\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x='day', y='tip_pct', row='time',
               col='smoker',
               kind='bar', data=tips[tips.tip_pct < 1]) # attention: row='time' here v.s. hue='time' in the above cell.

# %%
sns.factorplot(x='tip_pct', y='day', kind='box',
               data=tips[tips.tip_pct < 0.5])

# %%
from IPython.display import Image

# %%
Image(filename='IQR.png')

# %% [markdown]
# ## Other Python Visualization Tools

# %%
pd.options.display.max_rows = PREVIOUS_MAX_ROWS

# %% [markdown]
# ## Conclusion
